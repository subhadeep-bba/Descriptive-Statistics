# %% [markdown]
# 1. ANS - The most representative value of the bakery's weekly sales is
#  dozen because the dataset contains no outliers, making the median and mode perfectly capture the true center of the daily performance.

# %% [markdown]
# 2. ANS- The mean score for the quiz is 16.29. This average indicates a strong overall class performance, with most student marks leaning toward the higher end of the scale.

# %% [markdown]
# 3. ANS- The mode for the given dataset of shoe sizes is 8, it tells the manager exactly which shoe size is in the highest demand. The manager can prioritize reordering size 8 to prevent stockouts and satisfy the majority of customers.

# %% [markdown]
# 4. ANS-The median is a better measure of central tendency for this dataset because the \(\$50,000\) price acts as a major outlier that artificially inflates the mean.
#
#     The median for this group of cars is \(\$10,200\).

# %% [markdown]
# 5. ANS- The range of 15 minutes.

# %% [markdown]
# 6. ANS- The range of the weekly apple harvest weight is 22 kg.
# Knowing the range helps the farmer understand the variability in the weekly yields.

# %% [markdown]
# 7. ANS - Company A is more consistent. In statistics, variance measures how spread out a set of numbers is from their average. A lower variance means the data points are closer to the mean, which indicates greater consistency. Since Company A's variance (6) is lower than Company B's (15), its delivery delays fluctuate less, making its service more reliable.

# %% [markdown]
# 8. ANS- Coin B is the riskier investment because its higher standard deviation of \(\$120\) indicates greater volatility, meaning its daily prices fluctuate much more dramatically than Coin A's \(\$30\) standard deviation.

# %% [markdown]
# 9. ANS-  The mean electricity usage for the family is 414 kWh, and the standard deviation is 20.59 kWh . Together, these values indicate that the family has a highly stable, consistent, and predictable energy consumption pattern with minimal monthly variation.

# %% [markdown]
# 10. ANS - The statistical metrics for the player's performance are a Mean of 19.625, a Median of 19.5, no Mode, a Range of 10, a Sample Standard Deviation of 3.11. These values reveal a highly consistent and predictable scorer who safely produces close to 20 points per game without extreme performance variance.
